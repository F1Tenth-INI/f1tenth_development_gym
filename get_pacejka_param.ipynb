# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# read recording data
path = "ExperimentRecordings/"
file = "F1TENTH__2024-04-30_16-11-15_TEST_mpc_27Hz" + ".csv"
recording_data = pd.read_csv(path + file, delimiter=",", skiprows=7)

# read reference data
ref_path = "utilities/maps/"
map = "TEST"
file = map + "/" + map + "_wp.csv"
wp_data = pd.read_csv(ref_path + file, delimiter=",")
# Out:
# Index(['# s_m', 'x_m', 'y_m', 'psi_rad', 'kappa_radpm', 'vx_mps', 'ax_mps2'], dtype='object')

# %%
# plot the data

# %%
# calculate alpha_front and alpha_rear

alpha_front = math.arctan((v_y + lf*r) / (v_x))-delta
alpha_rear = math.arctan((v_y - lr*r) / (v_x))

# calculate Fyf and Fyr

Fyf = C_f * alpha_front
Fyr = C_r * alpha_rear
