# %%
import pandas as pd

# %%
df = pd.read_csv('../SI_Toolkit_ASF/Experiments/0_AL/Recordings_ETF1/Test/ETF1_pp.csv', skiprows=8)
df
# Out:
#        time  angular_vel_z  linear_vel_x  pose_theta  pose_theta_cos
# 0     7.055         -0.392         2.851      -1.379           0.191  \
# 1     7.155         -0.162         2.982      -1.346           0.223
# 2     7.254         -0.161         3.065      -1.329           0.239
# 3     7.358          0.156         3.179      -1.295           0.272
# 4     7.459          0.036         3.322      -1.327           0.241
# ..      ...            ...           ...         ...             ...
# 115  18.557          0.007         3.451      -1.322           0.246
# 116  18.656         -0.261         3.563      -1.282           0.285
# 117  18.757          0.063         3.746      -1.294           0.273
# 118  18.857         -0.252         3.820      -1.307           0.261
# 119  18.956          0.273         3.859      -1.290           0.277
#
#      pose_theta_sin  pose_x  pose_y  slip_angle  steering_angle  ...
# ...

# %%
df.angular_vel_z = -df.angular_vel_z
df
# Out:
#        time  angular_vel_z  linear_vel_x  pose_theta  pose_theta_cos
# 0     7.055          0.392         2.851      -1.379           0.191  \
# 1     7.155          0.162         2.982      -1.346           0.223
# 2     7.254          0.161         3.065      -1.329           0.239
# 3     7.358         -0.156         3.179      -1.295           0.272
# 4     7.459         -0.036         3.322      -1.327           0.241
# ..      ...            ...           ...         ...             ...
# 115  18.557         -0.007         3.451      -1.322           0.246
# 116  18.656          0.261         3.563      -1.282           0.285
# 117  18.757         -0.063         3.746      -1.294           0.273
# 118  18.857          0.252         3.820      -1.307           0.261
# 119  18.956         -0.273         3.859      -1.290           0.277
#
#      pose_theta_sin  pose_x  pose_y  slip_angle  steering_angle  ...
# ...

# %%
df.to_csv('../SI_Toolkit_ASF/Experiments/0_AL/Recordings_ETF1/Test/ETF1_pp copy.csv', mode='a', index=False)
