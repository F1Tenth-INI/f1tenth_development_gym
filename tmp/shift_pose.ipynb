# %%
import pandas as pd
import numpy as np

# %%
path = '../ExperimentRecordings/00_Test_ODE/'
file = 'track_low_mu'
df = pd.read_csv(f'{path}/{file}.csv', skiprows=8)
df
# Out:
#       time  angular_vel_z  linear_vel_x  pose_theta  pose_theta_cos
# 0     0.04          0.000         0.360       0.000           1.000  \
# 1     0.08          0.113         0.721       0.002           1.000
# 2     0.12          0.282         1.081       0.007           1.000
# 3     0.16          0.695         1.442       0.024           1.000
# 4     0.20          1.104         1.802       0.058           0.998
# ..     ...            ...           ...         ...             ...
# 993  39.76         -1.215         3.109     -17.847           0.538
# 994  39.80         -1.146         3.128     -17.896           0.579
# 995  39.84         -0.727         3.158     -17.936           0.611
# 996  39.88         -0.575         3.191     -17.961           0.630
# 997  39.92         -0.809         3.213     -17.987           0.650
#
#      pose_theta_sin  pose_x  pose_y  slip_angle  steering_angle  ...   mu
# 0             0.000   0.005   1.000       0.000           0.000  ...  0.6  \
# ...

# %%
df.pose_x += 1000
df.pose_y += 1000
df
# Out:
#       time  angular_vel_z  linear_vel_x  pose_theta  pose_theta_cos
# 0     0.04          0.000         0.360       0.000           1.000  \
# 1     0.08          0.113         0.721       0.002           1.000
# 2     0.12          0.282         1.081       0.007           1.000
# 3     0.16          0.695         1.442       0.024           1.000
# 4     0.20          1.104         1.802       0.058           0.998
# ..     ...            ...           ...         ...             ...
# 993  39.76         -1.215         3.109     -17.847           0.538
# 994  39.80         -1.146         3.128     -17.896           0.579
# 995  39.84         -0.727         3.158     -17.936           0.611
# 996  39.88         -0.575         3.191     -17.961           0.630
# 997  39.92         -0.809         3.213     -17.987           0.650
#
#      pose_theta_sin    pose_x    pose_y  slip_angle  steering_angle  ...   mu
# ...

# %%
# Copy the header --> Do this manually

# %%
df.to_csv(f'{path}/{file}_shifted_pose.csv', mode='a', index=False)
