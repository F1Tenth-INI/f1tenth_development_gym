# %%
from experiment_analysis import *

# Load the data
map_name = 'RCA2'
map_path = './../../utilities/maps/' + map_name  # if no img, set to None

# exper_folder_path = './physical/02_12/'
# car_data = 'F1TENTH__2024-02-12_18-36-13Recording1_RCA2_neural_50Hz_vel1.0_noise_c[0.0, 0.0].csv' # if no sim data, set to None

exper_folder_path = './sim/02_16/'
# car_data = 'F1TENTH__2024-02-16_15-42-07Recording1_RCA2_mpc_50Hz_vel1.0_noise_c[0.0, 0.0].csv' # if no sim data, set to None
car_data = 'F1TENTH__2024-02-16_18-48-50Recording1_RCA2_neural_50Hz_vel1.0_noise_c[0.0, 0.0].csv' # if no sim data, set to None
# car_data = 'F1TENTH__2024-02-16_18-57-13Recording1_RCA2_neural_50Hz_vel1.0_noise_c[0.0, 0.0].csv' # if no sim data, set to None



get_laptime_info(exper_folder_path, car_data)
get_position_error(map_path, map_name, exper_folder_path, car_data)
plot_wp(map_path, map_name, exper_folder_path, car_data)
# Out:
# Lap Times:
# 18.22
# 17.96
# 18.08
# 18.1
# 17.980000000000004
# distances to raceline
# Min: 3.444122557507162e-05
# Max: 0.7264443208538031
# Mean: 0.10041203935819391
# Std: 0.10477862151222243

# %%
from experiment_analysis import *


# Load the data
map_name = 'RCA2'
map_path = './../../utilities/maps/' + map_name  # if no img, set to None

# exper_folder_path = './physical/02_12/'
# car_data = 'F1TENTH__2024-02-12_18-36-13Recording1_RCA2_neural_50Hz_vel1.0_noise_c[0.0, 0.0].csv' # if no sim data, set to None

exper_folder_path = './physical/02_12/'
# car_data = 'F1TENTH__2024-02-16_15-42-07Recording1_RCA2_mpc_50Hz_vel1.0_noise_c[0.0, 0.0].csv' # if no sim data, set to None
# car_data = 'F1TENTH__2024-02-16_18-48-50Recording1_RCA2_neural_50Hz_vel1.0_noise_c[0.0, 0.0].csv' # if no sim data, set to None
experiment_recording_filename = 'F1TENTH__2024-02-12_18-36-13Recording1_RCA2_neural_50Hz_vel1.0_noise_c[0.0, 0.0].csv' # if no sim data, set to None



# Load the data
experiment_recording_path = os.path.join(exper_folder_path, experiment_recording_filename)
experiment_recording = pd.read_csv(experiment_recording_path, comment='#')

get_laptime_info(experiment_recording)
get_position_error(map_path, map_name, experiment_recording)
# plot_wp(map_path, map_name, exper_folder_path, car_data)
# Out:
# Lap Times:
# 25.359
# 19.921999999999997
# 20.164
# 19.961
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 23
#      20 experiment_recording = pd.read_csv(experiment_recording_path, comment='#')
#      22 get_laptime_info(experiment_recording)
# ---> 23 get_position_error(map_path, map_name, experiment_recording)
#      24 # plot_wp(map_path, map_name, exper_folder_path, car_data)
#
# TypeError: get_position_error() missing 1 required positional argument: 'filename'
