# %%
import os
os.chdir('../')
os.getcwd()
# Out:
# '/home/gianni/Files/Studium/Master/04_FS2023/MT/f1tenth_development_gym'

# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
from tmp.get_metrics import *

# %% [markdown]
# # Final plots

# %%
path = 'SI_Toolkit_ASF/Experiments/Experiment-0_final/Models/Dense-10IN-64H1-128H2-64H3-8OUT-0-0'
map_name = 'hangar12'

recording = f'{path}/training_recording.csv'
metrics = get_metrics_from_recording(recording, map_name)

# %%
plot_lap_times(metrics[0][1:], None)
