# %%
import os
os.chdir('../')
os.getcwd()
# Out:
# '/home/gianni/Files/Studium/Master/04_FS2023/MT/f1tenth_development_gym'

# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
# %matplotlib widget

# %% [markdown]
# # Final plots

# %%
# experiment_folder = 'SI_Toolkit_ASF/Experiments/0_tiv'
# df = pd.read_csv(f'{experiment_folder}/Models/Custom-7IN-tiv_module-TIVModelDNN-7OUT-0-0/log_training.csv', sep=';')
# df['time'] = df.index * 0.04
# df = df.set_index(df.time)
# # df.loss.plot(legend=True, label='High mu')

# df = pd.read_csv(f'{experiment_folder}/Models/Custom-7IN-tiv_module-TIVModelDNN-7OUT-0-6/log_training.csv', sep=';')
# df['time'] = df.index * 0.04
# df = df.set_index(df.time)
# df.loss.plot(legend=True, label='Low mu')

df = pd.read_csv(f'SI_Toolkit_ASF/Experiments/Experiment-5/Models/Custom-7IN-tiv_module-TIVModelDNN-7OUT-1-0/log_training.csv', sep=';')
df['time'] = df.index * 0.04
df = df.set_index(df.time)
df.loss.plot(legend=True, label='Low mu')

plt.ylabel('Loss []')
plt.xlabel('Time [s]')
plt.savefig('plots/plots/DNN_tiv.png')
